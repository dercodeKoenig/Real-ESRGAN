# %%
from basicsr.metrics import calculate_psnr, calculate_ssim
import cv2
import os
import numpy as np
from realesrgan.utils import RealESRGANerV2
from realesrgan.archs.rrdb_pixelshuffle_v3_arch import RRDBNet_v3

model = RRDBNet_v3(num_in_ch=3, num_out_ch=3, highway_channels=192, processing_channels=64, num_block=32,
                       num_grow_ch=32, num_pre_upscale_ch=256, scale=4, use_attention=True)

model_path = "../../../experiments/train_v3_attn_x4_m/models/net_g_700000.pth"
upscaler = RealESRGANerV2(
        scale=4,
        model_path=model_path,
        model=model,
)

lr_dir = "bicubic_4x/val/LR"
gt_dir = "bicubic_4x/val/HR"

psnr_list = []
ssim_list = []

for fname in os.listdir(lr_dir):
    lr_img = cv2.imread(os.path.join(lr_dir, fname), cv2.IMREAD_COLOR)
    gt_img = cv2.imread(os.path.join(gt_dir, fname), cv2.IMREAD_COLOR)
    print(lr_img.shape, gt_img.shape)

    sr_img, mode = upscaler.enhance(lr_img)

    sr_img = cv2.resize(sr_img, (gt_img.shape[1], gt_img.shape[0]))

    psnr = calculate_psnr(sr_img, gt_img, crop_border=4)
    ssim = calculate_ssim(sr_img, gt_img, crop_border=4)

    print(fname, f"PSNR: {psnr:.2f}, SSIM: {ssim:.4f}")

    psnr_list.append(psnr)
    ssim_list.append(ssim)
    
np.mean(ssim_list), np.mean(psnr_list)
# Out:
# (80, 120, 3) (321, 481, 3)
# 45096.png PSNR: 29.22, SSIM: 0.8483
# (80, 120, 3) (321, 481, 3)
# 43074.png PSNR: 26.83, SSIM: 0.7133
# (80, 120, 3) (321, 481, 3)
# 19021.png PSNR: 23.07, SSIM: 0.6139
# (120, 80, 3) (481, 321, 3)
# 42012.png PSNR: 24.39, SSIM: 0.6574
# (80, 120, 3) (321, 481, 3)
# 12084.png PSNR: 20.86, SSIM: 0.4913
# (80, 120, 3) (321, 481, 3)
# 109053.png PSNR: 25.18, SSIM: 0.6703
# (80, 120, 3) (321, 481, 3)
# 38082.png PSNR: 23.49, SSIM: 0.4389
# (120, 80, 3) (481, 321, 3)
# 102061.png PSNR: 22.78, SSIM: 0.7120
# (80, 120, 3) (321, 481, 3)
# 86016.png PSNR: 17.57, SSIM: 0.2009
# (80, 120, 3) (321, 481, 3)
# 157055.png PSNR: 22.34, SSIM: 0.6343
# (80, 120, 3) (321, 481, 3)
# 291000.png PSNR: 18.38, SSIM: 0.2696
# (80, 120, 3) (321, 481, 3)
# 197017.png PSNR: 24.48, SSIM: 0.6036
# (80, 120, 3) (321, 481, 3)
# 196073.png PSNR: 25.60, SSIM: 0.3804
# (80, 120, 3) (321, 481, 3)
# 86068.png PSNR: 24.31, SSIM: 0.4211
# (80, 120, 3) (321, 481, 3)
# 85048.png PSNR: 21.74, SSIM: 0.5482
# (80, 120, 3) (321, 481, 3)
# 69020.png PSNR: 23.93, SSIM: 0.4175
# (80, 120, 3) (321, 481, 3)
# 306005.png PSNR: 23.40, SSIM: 0.6170
# (80, 120, 3) (321, 481, 3)
# 170057.png PSNR: 24.98, SSIM: 0.5915
# (80, 120, 3) (321, 481, 3)
# 3096.png PSNR: 32.79, SSIM: 0.9489
# (80, 120, 3) (321, 481, 3)
# 219090.png PSNR: 23.45, SSIM: 0.6600
# (np.float64(0.5719255277877958), np.float64(23.939549204051463))
