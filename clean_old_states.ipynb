# %%
import os


for d in os.listdir("experiments"):
    d = "experiments/"+d
    print(d)
    try:
        states = os.listdir(d+"/training_states")
        l = []
        for i in states:
            if i.endswith(".state"):
                l.append(int(i.split(".")[0]))
        
        last_num = str(sorted(l)[-1])
        latest_name = last_num+".state"
        print(latest_name)
        
        for i in states:
            if i != latest_name:
                os.system("rm "+d+"/training_states/"+i)
                #print("rm "+d+"/training_states/"+i)
        
            
            
        models = os.listdir(d+"/models")
        for i in models:
            if not last_num in i:
                os.system("rm "+d+"/models/"+i)
    except Exception as e:
        print(e)
# Out:
# experiments/train_v2_x4_m
# 345000.state
# experiments/train_v2_attn_x4_m_exp
# 165000.state
# experiments/train_v5_m_archived_20251211_234753
# list index out of range
# experiments/train_unet_v3_m
# 1900000.state
# experiments/train_v2_attn_x4_m
# 505000.state
# experiments/train_v5_m_archived_20251212_000857
# list index out of range
# experiments/ft_lowgan_v3_attn_x4_m
# 199859.state
# experiments/train_unet_dynamic_iterative_res_xs
# 124000.state
# experiments/train_v3_dynamic_iterative_s
# 794383.state
# experiments/train_v5_m_archived_20251211_192904
# list index out of range
# experiments/ft1_v4_m
# list index out of range
# experiments/.ipynb_checkpoints
# [Errno 2] No such file or directory: 'experiments/.ipynb_checkpoints/training_states'
# experiments/train_v5_m_archived_20251211_234604
# list index out of range
# experiments/test
# list index out of range
# experiments/train_v5_m_archived_20251212_111350
# list index out of range
# experiments/ft_moredata_betterD_v3_attn_x4_m
# 20000.state
# experiments/ft1_v4_m_archived_20251211_154801
# list index out of range
# experiments/train_unet_dynamic_iterative_m
# list index out of range
# experiments/ft1_v4_m_archived_20251211_153656
# list index out of range
# experiments/train_v5_m_archived_20251211_175810
# list index out of range
# experiments/train_v3_attn_x4_m
# 810000.state
# experiments/train_v5_m_archived_20251212_023131
# list index out of range
# experiments/test_archived_20251211_172648
# list index out of range
# experiments/train_v4_m
# 50000.state
# experiments/train_v5_m_archived_20251212_021014
# list index out of range
# experiments/ft1_v4_m_archived_20251211_163441
# list index out of range
# experiments/test_archived_20251211_172052
# list index out of range
# experiments/train_v3_attn_x4_l
# list index out of range
# experiments/ft1_v4_m_archived_20251211_162338
# list index out of range
# experiments/test_archived_20251211_172704
# list index out of range
# experiments/train_unet_v2_xs
# 276000.state
# experiments/train_v5_m_archived_20251212_024858
# list index out of range
# experiments/train_v5_m_archived_20251212_014730
# list index out of range
# experiments/train_v4_m_archived_20251211_101501
# list index out of range
# experiments/train_unet_dynamic_iterative_res_xs_archived_20251125_094414
# list index out of range
# experiments/ft1_v4_m_archived_20251211_145159
# list index out of range
# experiments/train_v5_m_archived_20251212_111310
# 100000.state
# experiments/train_unet_v3_xs
# 540000.state
# experiments/train_v2_x4_s
# 6000.state
# experiments/ft1_v4_m_archived_20251211_165040
# list index out of range
# experiments/train_unet_dynamic_iterative_res3_xs_archived_20251126_163821
# 172000.state
# experiments/train_unet_dynamic_iterative_res3_xs
# 656000.state
# experiments/train_v4_m_archived_20251211_103505
# list index out of range
# experiments/train_unet_dynamic_iterative_res2_xs
# 56000.state
# experiments/train_v4_m_archived_20251211_100019
# 50000.state
# experiments/train_v2_attn_x4_s
# 855000.state
# experiments/train_v5_m_archived_20251212_005943
# list index out of range
# experiments/ft1_v4_m_archived_20251211_170623
# list index out of range
# experiments/test_archived_20251211_172338
# list index out of range
# experiments/test_archived_20251211_171314
# list index out of range
# experiments/train_v5_m
# 2750000.state
# rm: cannot remove 'experiments/train_unet_v3_m/training_states/.ipynb_checkpoints': Is a directory
# rm: cannot remove 'experiments/train_unet_v3_m/models/.ipynb_checkpoints': Is a directory
# rm: cannot remove 'experiments/train_v3_attn_x4_m/models/.ipynb_checkpoints': Is a directory
# rm: cannot remove 'experiments/train_v5_m_archived_20251212_111310/models/.ipynb_checkpoints': Is a directory
# rm: cannot remove 'experiments/train_unet_dynamic_iterative_res3_xs_archived_20251126_163821/training_states/.ipynb_checkpoints': Is a directory
# rm: cannot remove 'experiments/train_unet_dynamic_iterative_res3_xs_archived_20251126_163821/models/.ipynb_checkpoints': Is a directory
# rm: cannot remove 'experiments/train_v2_attn_x4_s/training_states/.ipynb_checkpoints': Is a directory
# rm: cannot remove 'experiments/train_v5_m/training_states/.ipynb_checkpoints': Is a directory
# experiments/ft1_v4_m_archived_20251211_152215
# list index out of range
# experiments/ft1_v4_m_archived_20251211_150711
# list index out of range
# experiments/train_v5_m_archived_20251212_025056
# list index out of range
# experiments/ft_lowgan_moredata_v3_attn_x4_m
# 10000.state
# experiments/train_v3_dynamic_s
# 164876.state
# experiments/ft_betterD_v3_attn_x4_m
# 95000.state
# experiments/train_unet_dynamic_iterative_xs
# 548000.state
# rm: cannot remove 'experiments/train_v5_m/models/.ipynb_checkpoints': Is a directory
